# %%
import numpy as np
import pandas as pd

# %%
df_Walmart = pd.read_csv("/Users/shivasagar/Downloads/DATA_SCIENCE/Python/Live PY/Classes/Project_Main/Walmart_Store_sales.csv")

# %%
df_Walmart
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df_Walmart.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
df_Walmart.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df_Walmart[['Store','Weekly_Sales', 'Holiday_Flag','Temperature','Fuel_Price', 'CPI', 'Unemployment']].describe(include = 'all')
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
missing_data = df_Walmart.isnull()
missing_data.head()
# Out:
#    Store   Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price    CPI  \
# 0  False  False         False         False        False       False  False
# 1  False  False         False         False        False       False  False
# 2  False  False         False         False        False       False  False
# 3  False  False         False         False        False       False  False
# 4  False  False         False         False        False       False  False
#
#    Unemployment
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
for column in missing_data.columns.values.tolist():
    
###1) print the column names
    print(missing_data[column].value_counts())
# Out:
# False    6435
# Name: Store, dtype: int64
# False    6435
# Name: Date, dtype: int64
# False    6435
# Name: Weekly_Sales, dtype: int64
# False    6435
# Name: Holiday_Flag, dtype: int64
# False    6435
# Name: Temperature, dtype: int64
# False    6435
# Name: Fuel_Price, dtype: int64
# False    6435
# Name: CPI, dtype: int64
# False    6435
# Name: Unemployment, dtype: int64

# %%
missing_data['Weekly_Sales'].value_counts()
# Out:
# False    6435
# Name: Weekly_Sales, dtype: int64

# %%
df_Walmart.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df_Walmart['Holiday_Flag'].value_counts()
# Out:
# 0    5985
# 1     450
# Name: Holiday_Flag, dtype: int64

# %%
#Converting into Date format
df_Walmart['Date'] = pd.to_datetime(df_Walmart['Date'], infer_datetime_format=True)

# %%
df_Walmart['Date'].describe()
# Out:
# count                    6435
# unique                    143
# top       2011-07-15 00:00:00
# freq                       45
# first     2010-01-10 00:00:00
# last      2012-12-10 00:00:00
# Name: Date, dtype: object

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df_Walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df_Walmart['Week'] = df_Walmart.Date.dt.week
df_Walmart['Year'] = df_Walmart.Date.dt.year
# df_Walmart['Day'] = df_Walmart.Date.dt.day

# %%
df_Walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Week  Year
# ...

# %%
# 1. Which store has maximum sales?
# Assumption 1: Individually Weekly_sales by Store in 2010, 2011, 2012
# Assumption 2: Combining Sales of each stores for individual year 2010, 2011 & 2012 respectively. 
# Assumption 3: Combining Sales of each stores for all the 3 years.

# %%
store_sales_2010 = df_Walmart[df_Walmart.Year==2010]['Weekly_Sales'].groupby(df_Walmart['Store']).max()
store_sales_2011 = df_Walmart[df_Walmart.Year==2011]['Weekly_Sales'].groupby(df_Walmart['Store']).max()
store_sales_2012 = df_Walmart[df_Walmart.Year==2012]['Weekly_Sales'].groupby(df_Walmart['Store']).max()

# %%
store_sales_2010
# Out:
# Store
# 1     2387950.20
# 2     3436007.68
# 3      605990.41
# 4     3526713.39
# 5      488362.61
# 6     2727575.18
# 7     1045124.88
# 8     1511641.09
# 9      873347.55
# 10    3749057.69
# 11    2306265.36
# 12    1768249.89
# 13    3595903.20
# 14    3818686.45
# 15    1368318.17
# 16    1004730.69
# 17    1309226.79
# 18    2027507.15
# 19    2678206.42
# 20    3766687.43
# 21    1587257.78
# 22    1962445.04
# 23    2734277.10
# 24    2386015.75
# 25    1295391.19
# 26    1573982.47
# 27    3078162.08
# 28    2026026.39
# 29    1130926.79
# 30     519354.88
# 31    2068942.97
# 32    1949183.14
# 33     331173.51
# 34    1620748.25
# 35    1781866.98
# 36     489372.02
# 37     576809.92
# 38     383657.44
# 39    2495489.25
# 40    1648829.18
# 41    2225016.73
# 42     607218.60
# 43     725043.04
# 44     365098.24
# 45    1682862.03
# Name: Weekly_Sales, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.lineplot(store_sales_2010.index, store_sales_2010.values)
sns.lineplot(store_sales_2011.index, store_sales_2011.values)
sns.lineplot(store_sales_2012.index, store_sales_2012.values)
plt.grid()
plt.legend(['2010','2011','2012'], loc='best', fontsize=14)
plt.title('Average_Weekly_Sales_of_Store - Year', fontsize=16)
plt.xlabel('Store', fontsize=20)
plt.ylabel('Individual_Weekly_Sales', fontsize=20)
plt.xticks(np.arange(1,46, step=1))
plt.show()

# %%
# The above graph shows the Maxi. weekly_sales of all stores individually representing for year 2010, 2011 & 2012. 
# From the graph we can say that:
# In 2010, represented by Blue line: Store 10, 14 & 20 has sales comparable with a peak in sales for store 14. 
# In 2011, represented by Orange line: Store 2, 13 & 20 has sales comparable with a peak in sales for store 4. 
# In 2012, represented by Green line: Store 4, 14 & 20 has sales comparable with a peak in sales for store 20. 

# Conclusion: Store 14 has maximum Weekly_Sales with respect to weeks comparision.

# %%
# Maximum_sales_store from all the 3 years: Store 14 shows the peak in 2010.  
maximum_sales_store = df_Walmart[df_Walmart['Weekly_Sales'] == df_Walmart['Weekly_Sales'].max()]

# %%
maximum_sales_store
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1905     14 2010-12-24    3818686.45             0        30.59       3.141
#
#             CPI  Unemployment  Week  Year
# 1905  182.54459         8.724    51  2010

# %%
# Assumption 2 : Summing all the Weekly_Sales for respective Stores and then finding the maximum sales for ind. years.

# %%
store_sales_2010_by_store = df_Walmart[df_Walmart.Year==2010]['Weekly_Sales'].groupby(df_Walmart['Store']).sum()
store_sales_2011_by_store = df_Walmart[df_Walmart.Year==2011]['Weekly_Sales'].groupby(df_Walmart['Store']).sum()
store_sales_2012_by_store = df_Walmart[df_Walmart.Year==2012]['Weekly_Sales'].groupby(df_Walmart['Store']).sum()

# %%
store_sales_2010_by_store
# Out:
# Store
# 1     7.327883e+07
# 2     9.527786e+07
# 3     1.874542e+07
# 4     9.568047e+07
# 5     1.483603e+07
# 6     7.691232e+07
# 7     2.556808e+07
# 8     4.320447e+07
# 9     2.512922e+07
# 10    9.447220e+07
# 11    6.525514e+07
# 12    4.837038e+07
# 13    9.527274e+07
# 14    1.054622e+08
# 15    3.202353e+07
# 16    2.472863e+07
# 17    4.110492e+07
# 18    5.597842e+07
# 19    7.258053e+07
# 20    1.017331e+08
# 21    3.763111e+07
# 22    5.086528e+07
# 23    6.770911e+07
# 24    6.689065e+07
# 25    3.513627e+07
# 26    4.839070e+07
# 27    9.001318e+07
# 28    6.477876e+07
# 29    2.694683e+07
# 30    2.173909e+07
# 31    6.556027e+07
# 32    5.519094e+07
# 33    1.276683e+07
# 34    4.615042e+07
# 35    5.219597e+07
# 36    2.115313e+07
# 37    2.450847e+07
# 38    1.658779e+07
# 39    6.578228e+07
# 40    4.635736e+07
# 41    5.773822e+07
# 42    2.549809e+07
# 43    3.153701e+07
# 44    1.360752e+07
# 45    3.853634e+07
# Name: Weekly_Sales, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.lineplot(store_sales_2010_by_store.index, store_sales_2010_by_store.values)
sns.lineplot(store_sales_2011_by_store.index, store_sales_2011_by_store.values)
sns.lineplot(store_sales_2012_by_store.index, store_sales_2012_by_store.values)
plt.grid()
plt.legend(['2010','2011','2012'], loc='best', fontsize=14)
plt.title('Average_Weekly_Sales_of_Store - Year', fontsize=16)
plt.xlabel('Store', fontsize=20)
plt.ylabel('Weekly_Sales_year_by_store', fontsize=20)
plt.xticks(np.arange(1,46, step=1))
plt.show()

# %%
# From the graph: In 2011, Store 4 has seen maximum sales.

# %%
store_sales_2010_by_store_maxi = store_sales_2010_by_store.max()

# %%
store_sales_2010_by_store_maxi # from the results Store 14 in 2010.
# Out:
# 105462242.38

# %%
store_sales_2011_by_store_maxi = store_sales_2011_by_store.max()

# %%
store_sales_2011_by_store_maxi # from the results Store 4 in 2011.
# Out:
# 111092293.32999998

# %%
store_sales_2012_by_store_maxi = store_sales_2012_by_store.max()

# %%
store_sales_2012_by_store_maxi # from the results Store 4 in 2012.
# Out:
# 92771189.23999998

# %%
# Assumption 3: Combining Sales of each stores for all the 3 years.

# %%
store_sales_by_store_all_years = df_Walmart['Weekly_Sales'].groupby(df_Walmart['Store']).sum()

# %%
store_sales_by_store_all_years
# Out:
# Store
# 1     2.224028e+08
# 2     2.753824e+08
# 3     5.758674e+07
# 4     2.995440e+08
# 5     4.547569e+07
# 6     2.237561e+08
# 7     8.159828e+07
# 8     1.299512e+08
# 9     7.778922e+07
# 10    2.716177e+08
# 11    1.939628e+08
# 12    1.442872e+08
# 13    2.865177e+08
# 14    2.889999e+08
# 15    8.913368e+07
# 16    7.425243e+07
# 17    1.277821e+08
# 18    1.551147e+08
# 19    2.066349e+08
# 20    3.013978e+08
# 21    1.081179e+08
# 22    1.470756e+08
# 23    1.987506e+08
# 24    1.940160e+08
# 25    1.010612e+08
# 26    1.434164e+08
# 27    2.538559e+08
# 28    1.892637e+08
# 29    7.714155e+07
# 30    6.271689e+07
# 31    1.996139e+08
# 32    1.668192e+08
# 33    3.716022e+07
# 34    1.382498e+08
# 35    1.315207e+08
# 36    5.341221e+07
# 37    7.420274e+07
# 38    5.515963e+07
# 39    2.074455e+08
# 40    1.378703e+08
# 41    1.813419e+08
# 42    7.956575e+07
# 43    9.056544e+07
# 44    4.329309e+07
# 45    1.123953e+08
# Name: Weekly_Sales, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.lineplot(store_sales_by_store_all_years.index, store_sales_by_store_all_years.values)
plt.grid()
plt.title('Average_Weekly_Sales_of_Store - All_Year', fontsize=16)
plt.xlabel('Store', fontsize=20)
plt.ylabel('Weekly_Sales_by_Store_all_years', fontsize=20)
plt.xticks(np.arange(1,46, step=1))
plt.show()

# %%
# From the graph and the results above: For all the Weekly_sales_by_store of all 3 years combined:
# Store 20 has maximum_sales of 3.013978e+08

# %%
# I went bit over and beyond for Weekly_Sales showing detailed analysis: Weekly_sales, each year and all yrs together.

# %%
# 2. Which store has maximum standard deviation i.e., the sales vary a lot. 
# Also, find out the coefficient of mean to standard deviation

# %%
# Assumption 1: Individual Std for year 2010, 2011 & 2012.
# Assumption 2: Combining Std for all the years.

# %%
store_sales_STD_2010 = df_Walmart[df_Walmart.Year==2010]['Weekly_Sales'].groupby(df_Walmart['Store']).std()
store_sales_STD_2011 = df_Walmart[df_Walmart.Year==2011]['Weekly_Sales'].groupby(df_Walmart['Store']).std()
store_sales_STD_2012 = df_Walmart[df_Walmart.Year==2012]['Weekly_Sales'].groupby(df_Walmart['Store']).std()

# %%
store_sales_STD_2010
# Out:
# Store
# 1     175249.325836
# 2     286501.060477
# 3      56107.780763
# 4     302449.759308
# 5      41623.193612
# 6     247633.722340
# 7     116968.235629
# 8     132703.188407
# 9      76662.159399
# 10    366059.644959
# 11    197282.181318
# 12    167198.025808
# 13    318291.323328
# 14    336759.641428
# 15    145291.819895
# 16     99006.846561
# 17    111237.505471
# 18    187468.463556
# 19    221821.473359
# 20    335859.866121
# 21    159694.789823
# 22    193158.501931
# 23    296465.658888
# 24    196049.749528
# 25    130961.029640
# 26    120691.529755
# 27    282027.527379
# 28    201200.112826
# 29    123347.731766
# 30     19894.376639
# 31    156039.042390
# 32    165396.321766
# 33     30868.870440
# 34    126460.392089
# 35    221889.375598
# 36     30451.197556
# 37     21299.484796
# 38     17467.481442
# 39    234078.100607
# 40    131188.096722
# 41    215475.473661
# 42     43313.950187
# 43     43237.259023
# 44     17039.383296
# 45    163710.927397
# ...

# %%
plt.figure(figsize=(20,10))
sns.lineplot(store_sales_STD_2010.index, store_sales_STD_2010.values)
sns.lineplot(store_sales_STD_2011.index, store_sales_STD_2011.values)
sns.lineplot(store_sales_STD_2012.index, store_sales_STD_2012.values)
plt.grid()
plt.legend(['2010','2011','2012'], loc='best', fontsize=14)
plt.title('Average_Weekly_Sales_STD - Year', fontsize=16)
plt.xlabel('Store', fontsize=20)
plt.ylabel('Weekly_Sales_STD', fontsize=20)
plt.xticks(np.arange(1,46, step=1))
plt.show()

# %%
store_sales_STD = df_Walmart['Weekly_Sales'].groupby(df_Walmart['Store']).std()

# %%
store_sales_STD
# Out:
# Store
# 1     155980.767761
# 2     237683.694682
# 3      46319.631557
# 4     266201.442297
# 5      37737.965745
# 6     212525.855862
# 7     112585.469220
# 8     106280.829881
# 9      69028.666585
# 10    302262.062504
# 11    165833.887863
# 12    139166.871880
# 13    265506.995776
# 14    317569.949476
# 15    120538.652043
# 16     85769.680133
# 17    112162.936087
# 18    176641.510839
# 19    191722.638730
# 20    275900.562742
# 21    128752.812853
# 22    161251.350631
# 23    249788.038068
# 24    167745.677567
# 25    112976.788600
# 26    110431.288141
# 27    239930.135688
# 28    181758.967539
# 29     99120.136596
# 30     22809.665590
# 31    125855.942933
# 32    138017.252087
# 33     24132.927322
# 34    104630.164676
# 35    211243.457791
# 36     60725.173579
# 37     21837.461190
# 38     42768.169450
# 39    217466.454833
# 40    119002.112858
# 41    187907.162766
# 42     50262.925530
# 43     40598.413260
# 44     24762.832015
# 45    130168.526635
# ...

# %%
store_sales_STD.max() # Store-14has maximum Std.
# Out:
# 317569.9494755081

# %%
plt.figure(figsize=(20,10))
sns.lineplot(store_sales_STD.index, store_sales_STD.values)
plt.grid()
plt.legend(['All Years'], loc='best', fontsize=14)
plt.title('Average_Weekly_Sales_STD - Store', fontsize=16)
plt.xlabel('Store', fontsize=20)
plt.ylabel('Weekly_Sales_STD', fontsize=20)
plt.xticks(np.arange(1,46, step=1))
plt.show()

plt.figure(figsize=(20,10))
sns.barplot(store_sales_STD.index, store_sales_STD.values, palette='dark')
plt.grid()
plt.title('Average_Weekly_Sales_STD - Store', fontsize=18)
plt.ylabel('Weekly_Sales_STD', fontsize=16)
plt.xlabel('Store', fontsize=16)
plt.show()

# %%
# The Store 14 has maximum STD of 317569.9494755081

# %%
#Also find the coeff. of mean to STD
store_sales_mean = df_Walmart['Weekly_Sales'].groupby(df_Walmart['Store']).mean()

# %%
store_sales_mean
# Out:
# Store
# 1     1.555264e+06
# 2     1.925751e+06
# 3     4.027044e+05
# 4     2.094713e+06
# 5     3.180118e+05
# 6     1.564728e+06
# 7     5.706173e+05
# 8     9.087495e+05
# 9     5.439806e+05
# 10    1.899425e+06
# 11    1.356383e+06
# 12    1.009002e+06
# 13    2.003620e+06
# 14    2.020978e+06
# 15    6.233125e+05
# 16    5.192477e+05
# 17    8.935814e+05
# 18    1.084718e+06
# 19    1.444999e+06
# 20    2.107677e+06
# 21    7.560691e+05
# 22    1.028501e+06
# 23    1.389864e+06
# 24    1.356755e+06
# 25    7.067215e+05
# 26    1.002912e+06
# 27    1.775216e+06
# 28    1.323522e+06
# 29    5.394514e+05
# 30    4.385796e+05
# 31    1.395901e+06
# 32    1.166568e+06
# 33    2.598617e+05
# 34    9.667816e+05
# 35    9.197250e+05
# 36    3.735120e+05
# 37    5.189003e+05
# 38    3.857317e+05
# 39    1.450668e+06
# 40    9.641280e+05
# 41    1.268125e+06
# 42    5.564039e+05
# 43    6.333247e+05
# 44    3.027489e+05
# 45    7.859814e+05
# Name: Weekly_Sales, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.barplot(store_sales_mean.index, store_sales_mean.values, palette='dark')
plt.grid()
plt.title('Average_Weekly_Sales_Mean - Stores', fontsize=18)
plt.ylabel('Sales_mean', fontsize=16)
plt.xlabel('Store', fontsize=16)
plt.show()

# %%
coeff_mean_to_STD = store_sales_mean/store_sales_STD

# %%
coeff_mean_to_STD
# Out:
# Store
# 1      9.970873
# 2      8.102160
# 3      8.694034
# 4      7.868902
# 5      8.426840
# 6      7.362531
# 7      5.068303
# 8      8.550456
# 9      7.880502
# 10     6.284032
# 11     8.179167
# 12     7.250300
# 13     7.546394
# 14     6.363884
# 15     5.171059
# 16     6.053978
# 17     7.966815
# 18     6.140790
# 19     7.536924
# 20     7.639263
# 21     5.872253
# 22     6.378248
# 23     5.564175
# 24     8.088169
# 25     6.255458
# 26     9.081773
# 27     7.398888
# 28     7.281744
# 29     5.442400
# 30    19.227797
# 31    11.091264
# 32     8.452336
# 33    10.767931
# 34     9.239989
# 35     4.353863
# 36     6.150859
# 37    23.761933
# 38     9.019129
# 39     6.670767
# 40     8.101772
# 41     6.748681
# 42    11.069866
# 43    15.599741
# 44    12.225939
# 45     6.038183
# Name: Weekly_Sales, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.lineplot(coeff_mean_to_STD.index, coeff_mean_to_STD.values)
plt.grid()
plt.legend(['All Years'], loc='best', fontsize=14)
plt.title('coeff_mean_to_STD - AllYears', fontsize=16)
plt.xlabel('Store', fontsize=20)
plt.ylabel('coeff_mean_to_STD', fontsize=20)
plt.xticks(np.arange(1,46, step=1))
plt.show()

# %%
# Cnclusion : Store 37 has highest coeff of mean to STD of 23.76.

# %%
df_Walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Week  Year
# ...

# %%
# 3. Which store/s has good quarterly growth rate in Q3’2012

# %%
df_Walmart['Qtr'] = df_Walmart['Date'].map(lambda Date: pd.Period(Date,'Q'))

# %%
df_Walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Week  Year     Qtr
# ...

# %%
#Finding the 2012Q3
Q3_2012_store_growth = df_Walmart[df_Walmart.Qtr=='2012Q3']['Weekly_Sales'].groupby(df_Walmart['Store']).sum()
Q2_2012_store_growth = df_Walmart[df_Walmart.Qtr=='2012Q2']['Weekly_Sales'].groupby(df_Walmart['Store']).sum()
Q1_2012_store_growth = df_Walmart[df_Walmart.Qtr=='2012Q1']['Weekly_Sales'].groupby(df_Walmart['Store']).sum()
Q4_2012_store_growth = df_Walmart[df_Walmart.Qtr=='2012Q4']['Weekly_Sales'].groupby(df_Walmart['Store']).sum()

# %%
plt.figure(figsize=(20,8))
sns.lineplot(Q3_2012_store_growth.index, Q3_2012_store_growth.values)
sns.lineplot(Q2_2012_store_growth.index, Q2_2012_store_growth.values)
sns.lineplot(Q1_2012_store_growth.index, Q1_2012_store_growth.values)
sns.lineplot(Q4_2012_store_growth.index, Q4_2012_store_growth.values)
plt.grid()
plt.legend(['2012Q3', '2012Q2','2012Q1','2012Q4' ], loc='best', fontsize=16)
plt.title('Weekly Sales-Store', fontsize=18)
plt.ylabel('Sales_Q2_Q3_2012', fontsize=16)
plt.xlabel('Store', fontsize=16)
plt.xticks(np.arange(1,46, step=1))
plt.show()

# %%
# From the graph: We can say that sales in Q2 is good than Q3. Which will be seen in negative growth rate. 
# Store 4 has highest sales with 25652119.35

# %%
df_growth_rate = [Q4_2012_store_growth, Q3_2012_store_growth,Q2_2012_store_growth, Q1_2012_store_growth]

# %%
df_growth_rate
result_df_growth_rate = pd.concat(df_growth_rate, axis=1)

# %%
result_df_growth_rate.pct_change(axis='columns')
# Out:
#        Weekly_Sales  Weekly_Sales  Weekly_Sales  Weekly_Sales
# Store
# 1               NaN      0.944852      0.129004     -0.099153
# 2               NaN      0.952519      0.120028     -0.101302
# 3               NaN      0.956978      0.120039     -0.108803
# 4               NaN      0.961835      0.106504     -0.096000
# 5               NaN      0.991978      0.140864     -0.116197
# 6               NaN      1.025811      0.130185     -0.122432
# 7               NaN      1.277419      0.039768     -0.052175
# 8               NaN      0.944619      0.097520     -0.092193
# 9               NaN      0.925037      0.138334     -0.108739
# 10              NaN      0.909825      0.114745     -0.051786
# 11              NaN      1.009741      0.110892     -0.093778
# 12              NaN      0.931823      0.120217     -0.070184
# 13              NaN      0.986384      0.102107     -0.129176
# 14              NaN      0.891551      0.212872     -0.090149
# ...

# %%
# Conclusion: Stores - Stores(from column 2) which have value greater than 1 have positive graowth rate.

# %%
# 4. Find out the holdiays which have higher sales than mean sales in non holiday season for all stores together. 
holiday_group = df_Walmart.groupby('Holiday_Flag')

# %%
holiday_group.size()
# Out:
# Holiday_Flag
# 0    5985
# 1     450
# dtype: int64

# %%
holiday_df = holiday_group.get_group(1)

# %%
holiday_df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 31        1 2010-10-09    1507460.69             1        78.69       2.565
# 42        1 2010-11-26    1955624.11             1        64.52       2.735
# 47        1 2010-12-31    1367320.01             1        48.43       2.943
# 53        1 2011-11-02    1649614.93             1        36.39       3.022
# ...     ...        ...           ...           ...          ...         ...
# 6375     45 2011-09-09     746129.56             1        71.48       3.738
# 6386     45 2011-11-25    1170672.94             1        48.71       3.492
# 6391     45 2011-12-30     869403.63             1        37.79       3.389
# 6397     45 2012-10-02     803657.12             1        37.00       3.640
# 6427     45 2012-07-09     766512.66             1        75.70       3.911
#
#              CPI  Unemployment  Week  Year     Qtr
# ...

# %%
Non_holiday_df = holiday_group.get_group(0)

# %%
Non_holiday_df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# 5         1 2010-12-03    1439541.59             0        57.79       2.667
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Week  Year     Qtr
# ...

# %%
Non_Holiday_mean = Non_holiday_df['Weekly_Sales'].mean()

# %%
Non_Holiday_mean
# Out:
# 1041256.3802088564

# %%
Holiday_sales_greater_than_nonholidaymean = holiday_df[holiday_df['Weekly_Sales']>Non_Holiday_mean]

# %%
Holiday_sales_greater_than_nonholidaymean
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 31        1 2010-10-09    1507460.69             1        78.69       2.565
# 42        1 2010-11-26    1955624.11             1        64.52       2.735
# 47        1 2010-12-31    1367320.01             1        48.43       2.943
# 53        1 2011-11-02    1649614.93             1        36.39       3.022
# ...     ...        ...           ...           ...          ...         ...
# 5819     41 2011-12-30    1264014.16             1        34.12       3.119
# 5825     41 2012-10-02    1238844.56             1        22.00       3.103
# 5855     41 2012-07-09    1392143.82             1        67.41       3.596
# 6334     45 2010-11-26    1182500.16             1        46.15       3.039
# 6386     45 2011-11-25    1170672.94             1        48.71       3.492
#
#              CPI  Unemployment  Week  Year     Qtr
# ...

# %%
plt.figure(figsize=(20,8))
sns.lineplot(Holiday_sales_greater_than_nonholidaymean.Store, Holiday_sales_greater_than_nonholidaymean.Weekly_Sales)
plt.grid()
plt.title('Holiday_sales_greater_than_nonholidaymean-Store', fontsize=18)
plt.ylabel('Holiday_sales_greater_than_nonholidaymean', fontsize=16)
plt.xlabel('Store', fontsize=16)
plt.xticks(np.arange(1,46, step=1))
plt.show()

# %%
# From the graph, we can clearly verify that Holiday_sales_greater_than_nonholidaymean is greater 
# than Non_Holiday_mean (1041256.3802088564)

# %%
plt.figure(figsize=(20,10))
sns.barplot(Holiday_sales_greater_than_nonholidaymean.Store, Holiday_sales_greater_than_nonholidaymean.Weekly_Sales, palette='dark')
plt.grid()
plt.title('Holiday_sales_greater_than_nonholidaymean-Store', fontsize=18)
plt.ylabel('Holiday_sales_greater_than_nonholidaymean', fontsize=16)
plt.xlabel('Store', fontsize=16)
plt.show()

# %%
# Comments: Clearly from the graph, We can say that Holiday_sales greater than the non holiday sales mean. i.e., 1041256.380

# %%
# 5. Provide a monthly and semester view of sales in units and give insights

# %%
df_Walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Week  Year     Qtr
# ...

# %%
df_Walmart['Year_Monthly'] = df_Walmart['Date'].map(lambda Date: pd.Period(Date,'M'))

# %%
df_Walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %%
store_sales_monthly_2010_01 = df_Walmart[df_Walmart.Year_Monthly=='2010-01']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_02 = df_Walmart[df_Walmart.Year_Monthly=='2010-02']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_03 = df_Walmart[df_Walmart.Year_Monthly=='2010-03']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_04 = df_Walmart[df_Walmart.Year_Monthly=='2010-04']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_05 = df_Walmart[df_Walmart.Year_Monthly=='2010-05']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_06 = df_Walmart[df_Walmart.Year_Monthly=='2010-06']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_07 = df_Walmart[df_Walmart.Year_Monthly=='2010-07']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_08 = df_Walmart[df_Walmart.Year_Monthly=='2010-08']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_09 = df_Walmart[df_Walmart.Year_Monthly=='2010-09']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_10 = df_Walmart[df_Walmart.Year_Monthly=='2010-10']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_11 = df_Walmart[df_Walmart.Year_Monthly=='2010-11']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2010_12 = df_Walmart[df_Walmart.Year_Monthly=='2010-12']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()

# %%
Monthly_Sales_2010_agg = [store_sales_monthly_2010_01,store_sales_monthly_2010_02,store_sales_monthly_2010_03,store_sales_monthly_2010_04,store_sales_monthly_2010_05,store_sales_monthly_2010_06,store_sales_monthly_2010_07,store_sales_monthly_2010_08,store_sales_monthly_2010_09,store_sales_monthly_2010_10,store_sales_monthly_2010_11,store_sales_monthly_2010_12]

# %%
Monthly_Sales_2010_agg_result = pd.concat(Monthly_Sales_2010_agg)

# %%
Monthly_Sales_2010_agg_result
# Out:
# Year_Monthly
# 2010-01    4.223988e+07
# 2010-02    1.915869e+08
# 2010-03    1.862262e+08
# 2010-04    1.838118e+08
# 2010-05    2.806119e+08
# 2010-06    1.424361e+08
# 2010-07    1.842664e+08
# 2010-08    1.845381e+08
# 2010-09    1.797041e+08
# 2010-10    2.311201e+08
# 2010-11    1.587731e+08
# 2010-12    3.235716e+08
# Freq: M, Name: Weekly_Sales, dtype: float64

# %%
store_sales_monthly_2011_01 = df_Walmart[df_Walmart.Year_Monthly=='2011-01']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_02 = df_Walmart[df_Walmart.Year_Monthly=='2011-02']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_03 = df_Walmart[df_Walmart.Year_Monthly=='2011-03']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_04 = df_Walmart[df_Walmart.Year_Monthly=='2011-04']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_05 = df_Walmart[df_Walmart.Year_Monthly=='2011-05']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_06 = df_Walmart[df_Walmart.Year_Monthly=='2011-06']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_07 = df_Walmart[df_Walmart.Year_Monthly=='2011-07']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_08 = df_Walmart[df_Walmart.Year_Monthly=='2011-08']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_09 = df_Walmart[df_Walmart.Year_Monthly=='2011-09']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_10 = df_Walmart[df_Walmart.Year_Monthly=='2011-10']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_11 = df_Walmart[df_Walmart.Year_Monthly=='2011-11']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2011_12 = df_Walmart[df_Walmart.Year_Monthly=='2011-12']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()

# %%
Monthly_Sales_2011_agg = [store_sales_monthly_2011_01,store_sales_monthly_2011_02,store_sales_monthly_2011_03,store_sales_monthly_2011_04,store_sales_monthly_2011_05,store_sales_monthly_2011_06,store_sales_monthly_2011_07,store_sales_monthly_2011_08,store_sales_monthly_2011_09,store_sales_monthly_2011_10,store_sales_monthly_2011_11,store_sales_monthly_2011_12]

# %%
Monthly_Sales_2011_agg_result = pd.concat(Monthly_Sales_2011_agg)

# %%
Monthly_Sales_2011_agg_result
# Out:
# Year_Monthly
# 2011-01    2.119657e+08
# 2011-02    1.876092e+08
# 2011-03    1.365205e+08
# 2011-04    2.789693e+08
# 2011-05    1.828017e+08
# 2011-06    1.401936e+08
# 2011-07    2.244611e+08
# 2011-08    1.880810e+08
# 2011-09    2.310323e+08
# 2011-10    1.837193e+08
# 2011-11    2.534703e+08
# 2011-12    2.293760e+08
# Freq: M, Name: Weekly_Sales, dtype: float64

# %%
store_sales_monthly_2012_01 = df_Walmart[df_Walmart.Year_Monthly=='2012-01']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_02 = df_Walmart[df_Walmart.Year_Monthly=='2012-02']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_03 = df_Walmart[df_Walmart.Year_Monthly=='2012-03']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_04 = df_Walmart[df_Walmart.Year_Monthly=='2012-04']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_05 = df_Walmart[df_Walmart.Year_Monthly=='2012-05']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_06 = df_Walmart[df_Walmart.Year_Monthly=='2012-06']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_07 = df_Walmart[df_Walmart.Year_Monthly=='2012-07']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_08 = df_Walmart[df_Walmart.Year_Monthly=='2012-08']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_09 = df_Walmart[df_Walmart.Year_Monthly=='2012-09']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_10 = df_Walmart[df_Walmart.Year_Monthly=='2012-10']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_11 = df_Walmart[df_Walmart.Year_Monthly=='2012-11']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()
store_sales_monthly_2012_12 = df_Walmart[df_Walmart.Year_Monthly=='2012-12']['Weekly_Sales'].groupby(df_Walmart['Year_Monthly']).sum()

# %%
Monthly_Sales_2012_agg = [store_sales_monthly_2012_01,store_sales_monthly_2012_02,store_sales_monthly_2012_03,store_sales_monthly_2012_04,store_sales_monthly_2012_05,store_sales_monthly_2012_06,store_sales_monthly_2012_07,store_sales_monthly_2012_08,store_sales_monthly_2012_09,store_sales_monthly_2012_10,store_sales_monthly_2012_11,store_sales_monthly_2012_12]

# %%
Monthly_Sales_2012_agg_result = pd.concat(Monthly_Sales_2012_agg)

# %%
Monthly_Sales_2012_agg_result
# Out:
# Year_Monthly
# 2012-01    1.722207e+08
# 2012-02    1.428296e+08
# 2012-03    2.307397e+08
# 2012-04    1.825428e+08
# 2012-05    1.422830e+08
# 2012-06    2.923883e+08
# 2012-07    1.845865e+08
# 2012-08    1.916126e+08
# 2012-09    1.797959e+08
# 2012-10    1.880794e+08
# 2012-11    4.692588e+07
# 2012-12    4.612851e+07
# Freq: M, Name: Weekly_Sales, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.barplot(Monthly_Sales_2010_agg_result.index, Monthly_Sales_2010_agg_result.values, palette='dark')
plt.grid()
plt.title('Sales_Monthly-Store', fontsize=18)
plt.ylabel('Monthly_Sales_2010_agg_result', fontsize=16)
plt.xlabel('Months', fontsize=16)
plt.show()

plt.figure(figsize=(20,10))
sns.barplot(Monthly_Sales_2011_agg_result.index, Monthly_Sales_2011_agg_result.values, palette='dark')
plt.grid()
plt.title('Sales_Monthly-Store', fontsize=18)
plt.ylabel('Monthly_Sales_2011_agg_result', fontsize=16)
plt.xlabel('Months', fontsize=16)
plt.show()

plt.figure(figsize=(20,10))
sns.barplot(Monthly_Sales_2012_agg_result.index, Monthly_Sales_2012_agg_result.values, palette='dark')
plt.grid()
plt.title('Sale_Monthly-Store', fontsize=18)
plt.ylabel('Monthly_Sales_2012_agg_result', fontsize=16)
plt.xlabel('Months', fontsize=16)
plt.show()

# %%
# Comments: In 2010, Monthly sales are peak in Dec & May, Lowest in Jan. All others months are comparatively same. 
# Comments: In 2011, Monthly sales are peak in Apr & Nov, Lowest in Mar & Jun. All others months are comparatively same. 
# Comments: In 2012, Monthly sales are peak in Jun, Lowest in Nov, Dec. All others months are comparatively same.

# %%
Months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
Months[0]
# Out:
# 'Jan'

# %%
# Months = np.array[1:12]
plt.figure(figsize=(20,8))
sns.lineplot(Months, Monthly_Sales_2010_agg_result.values, sort=False)
sns.lineplot(Months, Monthly_Sales_2011_agg_result.values, sort=False)
sns.lineplot(Months, Monthly_Sales_2012_agg_result.values, sort=False)
plt.grid()
plt.legend(['2010', '2011','2012'], loc='best', fontsize=16)
plt.title('Months_sales - Months', fontsize=18)
plt.ylabel('Monthly_Sales', fontsize=16)
plt.xlabel('Months', fontsize=16)
plt.show()

# %%
# Semester Sales : Assumption 3 Semesters i.e., Spring, Summer, Fall - 4 months each Semester

# %%
#2010
Semester_1_sales_2010 = [store_sales_monthly_2010_01,store_sales_monthly_2010_02,store_sales_monthly_2010_03,store_sales_monthly_2010_04]
Semester_2_sales_2010 = [store_sales_monthly_2010_05,store_sales_monthly_2010_06,store_sales_monthly_2010_07,store_sales_monthly_2010_08]
Semester_3_sales_2010 = [store_sales_monthly_2010_09,store_sales_monthly_2010_10,store_sales_monthly_2010_11,store_sales_monthly_2010_12]

#2011
Semester_1_sales_2011 = [store_sales_monthly_2011_01,store_sales_monthly_2011_02,store_sales_monthly_2011_03,store_sales_monthly_2011_04]
Semester_2_sales_2011 = [store_sales_monthly_2011_05,store_sales_monthly_2011_06,store_sales_monthly_2011_07,store_sales_monthly_2011_08]
Semester_3_sales_2011 = [store_sales_monthly_2011_09,store_sales_monthly_2011_10,store_sales_monthly_2011_11,store_sales_monthly_2011_12]

#2012
Semester_1_sales_2012 = [store_sales_monthly_2012_01,store_sales_monthly_2012_02,store_sales_monthly_2012_03,store_sales_monthly_2012_04]
Semester_2_sales_2012 = [store_sales_monthly_2012_05,store_sales_monthly_2012_06,store_sales_monthly_2012_07,store_sales_monthly_2012_08]
Semester_3_sales_2012 = [store_sales_monthly_2012_09,store_sales_monthly_2012_10,store_sales_monthly_2012_11,store_sales_monthly_2012_12]

# %%
#2010
Semester_1_sales_2010_result = pd.concat(Semester_1_sales_2010)
Semester_1_sales_2010_result_Value = Semester_1_sales_2010_result.sum()
Semester_2_sales_2010_result = pd.concat(Semester_2_sales_2010)
Semester_2_sales_2010_result_Value = Semester_2_sales_2010_result.sum()
Semester_3_sales_2010_result = pd.concat(Semester_3_sales_2010)
Semester_3_sales_2010_result_Value = Semester_3_sales_2010_result.sum()
Semester_sales_2010 = [Semester_1_sales_2010_result_Value,Semester_2_sales_2010_result_Value,Semester_3_sales_2010_result_Value]
Semester_sales_2010

#2011
Semester_1_sales_2011_result = pd.concat(Semester_1_sales_2011)
Semester_1_sales_2011_result_Value = Semester_1_sales_2011_result.sum()
Semester_2_sales_2011_result = pd.concat(Semester_2_sales_2011)
Semester_2_sales_2011_result_Value = Semester_2_sales_2011_result.sum()
Semester_3_sales_2011_result = pd.concat(Semester_3_sales_2011)
Semester_3_sales_2011_result_Value = Semester_3_sales_2011_result.sum()
Semester_sales_2011 = [Semester_1_sales_2011_result_Value,Semester_2_sales_2011_result_Value,Semester_3_sales_2011_result_Value]
Semester_sales_2011

#2012
Semester_1_sales_2012_result = pd.concat(Semester_1_sales_2012)
Semester_1_sales_2012_result_Value = Semester_1_sales_2012_result.sum()
Semester_2_sales_2012_result = pd.concat(Semester_2_sales_2012)
Semester_2_sales_2012_result_Value = Semester_2_sales_2012_result.sum()
Semester_3_sales_2012_result = pd.concat(Semester_3_sales_2012)
Semester_3_sales_2012_result_Value = Semester_3_sales_2012_result.sum()
Semester_sales_2012 = [Semester_1_sales_2012_result_Value,Semester_2_sales_2012_result_Value,Semester_3_sales_2012_result_Value]
Semester_sales_2012
# Out:
# [728332755.0, 810870386.0199999, 460929718.33000004]

# %%
Semester = ['Spring', 'Summer','Fall']

# %%
plt.figure(figsize=(10,8))
sns.lineplot(Semester, Semester_sales_2010, sort=False)
sns.lineplot(Semester, Semester_sales_2011, sort=False)
sns.lineplot(Semester, Semester_sales_2012, sort=False)
plt.grid()
plt.legend(['2010', '2011','2012'], loc='best', fontsize=16)
plt.title('Semester_sales - Semesters', fontsize=18)
plt.ylabel('Semester_Sales', fontsize=16)
plt.xlabel('Semesters', fontsize=16)
plt.show()

# %%
# Comments: In 2010, Semester sales are increasing over the end of the year, being low in Spring and peak in Fall. 
# Comments: In 2011, Semester sales are high in Spring & Fall, being low in Summer. 
# Comments: In 2012, Semester sales are high in Summer, being low in Fall.

# %%
# Linear Regression – Utilize variables like date and restructure dates as 1 for 5 Feb 2010 
# (starting from the earliest date in order). 
# Hypothesize if CPI, unemployment, and fuel price have any impact on sales.

# %%
df_Walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %%
df_Walmart_Store_data = df_Walmart.groupby('Store')

# %%
df_Walmart_Store_1 = df_Walmart_Store_data.get_group(1)

# %%
df_Walmart_Store_1
# Out:
#      Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0        1 2010-05-02    1643690.90             0        42.31       2.572
# 1        1 2010-12-02    1641957.44             1        38.51       2.548
# 2        1 2010-02-19    1611968.17             0        39.93       2.514
# 3        1 2010-02-26    1409727.59             0        46.63       2.561
# 4        1 2010-05-03    1554806.68             0        46.50       2.625
# ..     ...        ...           ...           ...          ...         ...
# 138      1 2012-09-28    1437059.26             0        76.08       3.666
# 139      1 2012-05-10    1670785.97             0        68.55       3.617
# 140      1 2012-12-10    1573072.81             0        62.99       3.601
# 141      1 2012-10-19    1508068.77             0        67.97       3.594
# 142      1 2012-10-26    1493659.74             0        69.16       3.506
#
#             CPI  Unemployment  Week  Year     Qtr Year_Monthly
# ...

# %%
df_Walmart_Store_1.describe()
# Out:
#        Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# count  143.0  1.430000e+02    143.000000   143.000000  143.000000  143.000000
# mean     1.0  1.555264e+06      0.069930    68.306783    3.219699  215.996892
# std      0.0  1.559808e+05      0.255926    14.250486    0.427313    4.350890
# min      1.0  1.316899e+06      0.000000    35.400000    2.514000  210.337426
# 25%      1.0  1.458105e+06      0.000000    58.265000    2.764500  211.549277
# 50%      1.0  1.534850e+06      0.000000    69.640000    3.290000  215.459905
# 75%      1.0  1.614892e+06      0.000000    80.485000    3.594000  220.531330
# max      1.0  2.387950e+06      1.000000    91.650000    3.907000  223.444251
#
#        Unemployment        Week         Year
# count    143.000000  143.000000   143.000000
# mean       7.610420   26.000000  2010.965035
# std        0.383749   14.561671     0.799759
# min        6.573000    1.000000  2010.000000
# ...

# %%
df_Walmart_Store_1.index+=1

# %%
df_Walmart_Store_1['Date'] = df_Walmart_Store_1.index
# Out:
# /Users/shivasagar/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Walmart_Store_1
# Out:
#      Store  Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1        1     1    1643690.90             0        42.31       2.572
# 2        1     2    1641957.44             1        38.51       2.548
# 3        1     3    1611968.17             0        39.93       2.514
# 4        1     4    1409727.59             0        46.63       2.561
# 5        1     5    1554806.68             0        46.50       2.625
# ..     ...   ...           ...           ...          ...         ...
# 139      1   139    1437059.26             0        76.08       3.666
# 140      1   140    1670785.97             0        68.55       3.617
# 141      1   141    1573072.81             0        62.99       3.601
# 142      1   142    1508068.77             0        67.97       3.594
# 143      1   143    1493659.74             0        69.16       3.506
#
#             CPI  Unemployment  Week  Year     Qtr Year_Monthly
# 1    211.096358         8.106    17  2010  2010Q2      2010-05
# ...

# %%
# Clearly we will start the problem as linear regression considering it as multiple linear regaression
# because of no. of paramters

# %%
# Checking as per the question whether Date and Store might be used in linear regression

# %%
x_features_D_S = df_Walmart_Store_1[df_Walmart_Store_1.Store==1][['Store', 'Date']]

# %%
x_features_D_S
# Out:
#      Store  Date
# 1        1     1
# 2        1     2
# 3        1     3
# 4        1     4
# 5        1     5
# ..     ...   ...
# 139      1   139
# 140      1   140
# 141      1   141
# 142      1   142
# 143      1   143
#
# [143 rows x 2 columns]

# %%
y_target = df_Walmart_Store_1[df_Walmart_Store_1.Store==1][['Weekly_Sales']]

# %%
y_target
# Out:
#      Weekly_Sales
# 1      1643690.90
# 2      1641957.44
# 3      1611968.17
# 4      1409727.59
# 5      1554806.68
# ..            ...
# 139    1437059.26
# 140    1670785.97
# 141    1573072.81
# 142    1508068.77
# 143    1493659.74
#
# [143 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_features_D_S, y_target, random_state=1)

# %%
x_train
x_test
y_train
y_test
# Out:
#      Weekly_Sales
# 79     1624383.75
# 117    1468928.37
# 32     1507460.69
# 6      1439541.59
# 126    1540421.49
# 46     1891034.93
# 15     1494251.50
# 45     1682614.26
# 74     1488538.09
# 90     1502562.78
# 131    1631135.79
# 54     1649614.93
# 86     1380020.27
# 94     1539483.70
# 30     1449142.92
# 17     1432069.95
# 36     1508239.93
# 91     1445249.09
# 84     1540471.24
# 20     1503284.06
# 41     1494479.49
# 93     1594938.89
# 123    1697230.96
# 99     2270188.99
# 60     1541102.38
# 43     1955624.11
# 34     1351791.03
# 100    1497462.72
# 70     1635078.41
# 98     1881176.67
# 18     1615524.71
# 29     1513080.49
# 66     1629391.28
# 110    1675431.16
# 116    1521577.87
# 67     1604775.58

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# array([1485645.03880204])

# %%
lm.coef_
# Out:
# array([[  0.       , 794.4864598]])

# %%
# Comments: The below Equation Multipe Linear Regression is shown below:

# %%
# Linear Equation: y_train = 1485645.0388 + 0*(x_train.Store) + 794.486*(x_train.Date)

# %%
import seaborn as sns
# %matplotlib inline

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="Date", y="Weekly_Sales", data=df_Walmart_Store_1)
plt.legend(['For Store1'], loc='best', fontsize=16)
plt.show()

# %%
# Comment: From the graph, the Weekly_Sales is slightly positively correlated, so it means the sales keeps increasing
# from Jan 2010 to Dec 2012. The Reg line shows kind of best fit.

# %%
#Let's calculate the R^2:
lm.fit(x_features_D_S, y_target)
print('R-square is: ', lm.score(x_features_D_S, y_target))
# Out:
# R-square is:  0.04602707509407655

# %%
Yhat = lm.predict(x_features_D_S)
print('The first four predicted value:', Yhat[0:4])
# Out:
# The first four predicted value: [[1497908.58333333]
#  [1498716.41170262]
#  [1499524.2400719 ]
#  [1500332.06844118]]

# %%
#MSE
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
mse = mean_squared_error(y_target, Yhat)
print('MSE of predicted price :',mse)
print('RMSE:',sqrt(mse))
# Out:
# MSE of predicted price : 23047852358.984245
# RMSE: 151815.19146312153

# %%
# For Linear Regression R-Square Value is: 0.04602707509407655
# MSE of predicted price : 23047852358.984245
# RMSE: 151815.19146312153
# The R-square value is pretty low for sales. 0.046(less that 0.05) and the null hypothesis is rejected and
# We will do Alternate Hypothesis now considering CPI, Unemployment and Fuel Price.

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df_Walmart_Store_1['CPI'],df_Walmart_Store_1['Weekly_Sales'])
plt.show()

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df_Walmart_Store_1['Unemployment'],df_Walmart_Store_1['Weekly_Sales'])
plt.show()

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df_Walmart_Store_1['Fuel_Price'],df_Walmart_Store_1['Weekly_Sales'])
plt.show()

# %%
# Comments: All the above plots shows, the Weekly_Sales Vs CPI, Unemployment & Fuel_price are scattered around X-axis
# which makes us to consider as a linear model is more appriorate for this data.

# %%
# Finding correlation if  CPI, unemployment, and fuel price have any impact on sales.

# %%
df_Walmart_Store_1[['CPI', 'Unemployment', 'Fuel_Price']].corr()
# Out:
#                    CPI  Unemployment  Fuel_Price
# CPI           1.000000     -0.813471    0.755259
# Unemployment -0.813471      1.000000   -0.513944
# Fuel_Price    0.755259     -0.513944    1.000000

# %%
# As the variable Unemployment & Fuel_price are strongly correlated, so we will use drop fuel price from the above.

# %%
feature_data = df_Walmart_Store_1[df_Walmart_Store_1['Store']==1][['Store','CPI','Unemployment','Fuel_Price']]

# %%
feature_data
# Out:
#      Store         CPI  Unemployment  Fuel_Price
# 1        1  211.096358         8.106       2.572
# 2        1  211.242170         8.106       2.548
# 3        1  211.289143         8.106       2.514
# 4        1  211.319643         8.106       2.561
# 5        1  211.350143         8.106       2.625
# ..     ...         ...           ...         ...
# 139      1  222.981658         6.908       3.666
# 140      1  223.181477         6.573       3.617
# 141      1  223.381296         6.573       3.601
# 142      1  223.425723         6.573       3.594
# 143      1  223.444251         6.573       3.506
#
# [143 rows x 4 columns]

# %%
# First we will analyse considering it as Multi-linear Regression problem and see the corresponding values:

# %%
lm.fit(feature_data,y_target)
print('R-squared  :', lm.score(feature_data, y_target))
# Out:
# R-squared  : 0.08498555789995767

# %%
# MSE and RMSE
Y_predict_Multifit = lm.predict(feature_data)
print('MSE :', mean_squared_error(y_target, Y_predict_Multifit))
print('RMSE :', sqrt(mean_squared_error(y_target, Y_predict_Multifit)))
# Out:
# MSE : 22106620866.561626
# RMSE : 148682.95418965022

# %%
# Comments: Comparing with Multiple Linear Regression, R-square is less. 
# We will anlayze using logistic Regression Analysis.
# R-squared  : 0.08498555789995767
# MSE : 22106620866.561626
# RMSE : 148682.95418965022

# %%
plt.figure(figsize=(width, height))

ax1 = sns.distplot(y_target, hist=False, color="r", label="Actual")
sns.distplot(Y_predict_Multifit, hist=False, color="b", label="Fitted",ax=ax1)

plt.title('Actual vs Fitted values for Weekly_Sales')
plt.xlabel('Weekly_Sales')
plt.ylabel('Y_predict_Multifit')

plt.show()
plt.close()

# %%
# Comments: The above graph clearly explains data is over-fitting.

# %%
response_of_cpi = df_Walmart_Store_1[df_Walmart_Store_1['Store'] ==1]['CPI'].astype('int64')
response_of_unemployment = df_Walmart_Store_1[df_Walmart_Store_1['Store'] ==1]['Unemployment'].astype('int64')

# %%
response_of_cpi
response_of_unemployment
# Out:
# 1      8
# 2      8
# 3      8
# 4      8
# 5      8
#       ..
# 139    6
# 140    6
# 141    6
# 142    6
# 143    6
# Name: Unemployment, Length: 143, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train_cpi,x_test_cpi,y_train_cpi,y_test_cpi = train_test_split(feature_data,response_of_cpi,random_state=1)
x_train_unemp,x_test_unemp,y_train_unemp,y_test_unemp = train_test_split(feature_data,response_of_unemployment,random_state=1)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=10000)
logreg.fit(x_train_cpi,y_train_cpi)
y_pred = logreg.predict(x_test_cpi)
logreg.fit(x_train_unemp,y_train_unemp)
y_pred_unemp = logreg.predict(x_test_unemp)

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test_cpi,y_pred))
print(metrics.accuracy_score(y_test_unemp,y_pred_unemp))
# Out:
# 0.7222222222222222
# 0.9444444444444444

# %%
print('cpi actual :', y_test_cpi.values[0:30])
print('cpi Predicted :', y_pred[0:30])
print('actual Unemployment :', y_test_unemp.values[0:30])
print('Predicted Unemployment :', y_pred_unemp[0:30])
# Out:
# cpi actual : [215 221 211 211 221 211 210 211 215 217 221 212 216 218 211 210 211 217
#  215 211 212 217 221 219 214 211 211 219 215 219]
# cpi Predicted : [215 221 211 211 221 211 211 211 215 215 221 211 215 218 211 211 211 217
#  215 211 211 217 221 221 215 211 211 221 215 220]
# actual Unemployment : [7 7 7 8 7 7 7 7 7 7 6 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7]
# Predicted Unemployment : [7 7 7 7 6 7 7 7 7 7 6 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7]

# %%
# Comments: CPI and Unemployment Accuracy Scores are 72.23% and 94.45% which is considerably high for this parameters.
# Logistic Regression Model would be the best model for good Accuracy.

# %%
# Change dates into days by creating new variable.

# %%
df_Walmart['Day_Description'] = pd.to_datetime(df_Walmart['Date']).dt.day_name()

# %%
df_Walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...
